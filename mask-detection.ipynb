# %% [markdown]
# # Dependencies

# %%
# !pip install torch==1.8.2+cpu torchvision==0.9.2+cpu torchaudio===0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Requirement already satisfied: torch==1.8.2+cpu in c:\users\danny\anaconda3\lib\site-packages (1.8.2+cpu)
# Requirement already satisfied: torchvision==0.9.2+cpu in c:\users\danny\anaconda3\lib\site-packages (0.9.2+cpu)
# Requirement already satisfied: torchaudio===0.8.2 in c:\users\danny\anaconda3\lib\site-packages (0.8.2)
# Requirement already satisfied: typing-extensions in c:\users\danny\anaconda3\lib\site-packages (from torch==1.8.2+cpu) (3.10.0.2)
# Requirement already satisfied: numpy in c:\users\danny\anaconda3\lib\site-packages (from torch==1.8.2+cpu) (1.20.3)
# Requirement already satisfied: pillow>=4.1.1 in c:\users\danny\anaconda3\lib\site-packages (from torchvision==0.9.2+cpu) (8.4.0)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (1.20.3)
# Requirement already satisfied: opencv-python>=4.1.2 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (4.5.5.64)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (8.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (2.26.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (1.7.1)
# Requirement already satisfied: torch>=1.7.0 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.8.2+cpu)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (0.9.2+cpu)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (4.62.3)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (2.8.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 20)) (1.3.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 21)) (0.11.2)
# Requirement already satisfied: thop in c:\users\danny\anaconda3\lib\site-packages (from -r requirements.txt (line 37)) (0.0.31.post2005241907)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danny\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\danny\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\danny\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\danny\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\danny\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danny\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\danny\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danny\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.2)
# Requirement already satisfied: typing-extensions in c:\users\danny\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 11)) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\danny\anaconda3\lib\site-packages (from tqdm>=4.41.0->-r requirements.txt (line 13)) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (58.0.4)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.20.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.44.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (2.6.5)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\users\danny\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.37.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\danny\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 20)) (2021.3)
# Requirement already satisfied: six in c:\users\danny\anaconda3\lib\site-packages (from absl-py>=0.4->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\danny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\danny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\danny\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\danny\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\danny\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\danny\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\danny\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 16)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\danny\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 16)) (3.2.0)

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Danny/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-4-15 torch 1.8.2+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): Model(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode=nearest)
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode=nearest)
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # Image Detections

# %%
#testing model against default COCO classes
img = 'https://www.skigranitepeak.com/wp-content/uploads/bb-plugin/cache/awesome_trio2-panorama.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 809x1619 3 persons, 2 skiss, 1 snowboard
# Speed: 817.7ms pre-process, 169.3ms inference, 15.6ms NMS per image at shape (1, 3, 320, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %% [markdown]
# # Video Detections

# %%
#Testing against stock footage driving video
cap = cv2.VideoCapture('driving.mp4')

while cap.isOpened():
    ret, frame = cap.read()
    
    
    
    results = model(frame)
    
    cv2.imshow('Object Detection', np.squeeze(results.render()))
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Webcam Detection

# %%
#Allows webcam detection of coco objects
cap = cv2.VideoCapture(1)
while cap.isOpened():
    ret, frame = cap.read()
    
    results = model(frame)
    
    cv2.imshow('Object Detection', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Train Custom Model

# %%
import uuid #used to name images
import os #file paths
import time #break between image collection

# %%
IMAGES_PATH = os.path.join('data', 'images') #Setting image path: data/images 
labels = ['no mask', 'mask']
number_images = 20

# %%
cap = cv2.VideoCapture(0)

#label loop
for label in labels:
    print("Collecting images for {}".format(label))
    time.sleep(5)
    
    #image loop
    for img_num in range(number_images):
        print("Collecting images for {}, image number {}".format(label, img_num))
        
        ret, frame = cap.read()
        
        #sets the location and format of image
        image_name = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        #writes the current webcam frame into image_name which contains path and format
        cv2.imwrite(image_name, frame)
        
        #shows image
        cv2.imshow('Image Collection', frame)
        
        #allows delay to reposition for next image capture
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for no mask
# Collecting images for no mask, image number 0
# Collecting images for no mask, image number 1
# Collecting images for no mask, image number 2
# Collecting images for no mask, image number 3
# Collecting images for no mask, image number 4
# Collecting images for no mask, image number 5
# Collecting images for no mask, image number 6
# Collecting images for no mask, image number 7
# Collecting images for no mask, image number 8
# Collecting images for no mask, image number 9
# Collecting images for no mask, image number 10
# Collecting images for no mask, image number 11
# Collecting images for no mask, image number 12
# Collecting images for no mask, image number 13
# Collecting images for no mask, image number 14
# Collecting images for no mask, image number 15
# Collecting images for no mask, image number 16
# Collecting images for no mask, image number 17
# Collecting images for no mask, image number 18
# Collecting images for no mask, image number 19
# Collecting images for mask
# Collecting images for mask, image number 0
# Collecting images for mask, image number 1
# Collecting images for mask, image number 2
# Collecting images for mask, image number 3
# Collecting images for mask, image number 4
# Collecting images for mask, image number 5
# Collecting images for mask, image number 6
# Collecting images for mask, image number 7
# Collecting images for mask, image number 8
# Collecting images for mask, image number 9
# Collecting images for mask, image number 10
# Collecting images for mask, image number 11
# Collecting images for mask, image number 12
# Collecting images for mask, image number 13
# Collecting images for mask, image number 14
# Collecting images for mask, image number 15
# Collecting images for mask, image number 16
# Collecting images for mask, image number 17
# Collecting images for mask, image number 18
# Collecting images for mask, image number 19

# %%
for label in labels:
    print("Collecting images for {}".format(label))
    for img_num in range(number_images):
        print("Collecting images for {}, image number {}".format(label, img_num))
        image_name = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(image_name)
# Out:
# Collecting images for no mask
# Collecting images for no mask, image number 0
# data\images\no mask.5a9a9153-bd32-11ec-ab86-04d9f5803693.jpg
# Collecting images for no mask, image number 1
# data\images\no mask.5a9a9154-bd32-11ec-b966-04d9f5803693.jpg
# Collecting images for no mask, image number 2
# data\images\no mask.5a9a9155-bd32-11ec-8c3a-04d9f5803693.jpg
# Collecting images for no mask, image number 3
# data\images\no mask.5a9a9156-bd32-11ec-82e1-04d9f5803693.jpg
# Collecting images for no mask, image number 4
# data\images\no mask.5a9a9157-bd32-11ec-8abc-04d9f5803693.jpg
# Collecting images for no mask, image number 5
# data\images\no mask.5a9a9158-bd32-11ec-bb73-04d9f5803693.jpg
# Collecting images for no mask, image number 6
# data\images\no mask.5a9a9159-bd32-11ec-ab6d-04d9f5803693.jpg
# Collecting images for no mask, image number 7
# data\images\no mask.5a9a915a-bd32-11ec-9eb4-04d9f5803693.jpg
# Collecting images for no mask, image number 8
# data\images\no mask.5a9a915b-bd32-11ec-8b4a-04d9f5803693.jpg
# Collecting images for no mask, image number 9
# data\images\no mask.5a9a915c-bd32-11ec-9866-04d9f5803693.jpg
# Collecting images for no mask, image number 10
# data\images\no mask.5a9a915d-bd32-11ec-949e-04d9f5803693.jpg
# Collecting images for no mask, image number 11
# data\images\no mask.5a9ab868-bd32-11ec-85e2-04d9f5803693.jpg
# Collecting images for no mask, image number 12
# data\images\no mask.5a9ab869-bd32-11ec-ba7a-04d9f5803693.jpg
# Collecting images for no mask, image number 13
# data\images\no mask.5a9ab86a-bd32-11ec-9b30-04d9f5803693.jpg
# Collecting images for no mask, image number 14
# data\images\no mask.5a9ab86b-bd32-11ec-b298-04d9f5803693.jpg
# Collecting images for no mask, image number 15
# data\images\no mask.5a9ab86c-bd32-11ec-9f00-04d9f5803693.jpg
# Collecting images for no mask, image number 16
# data\images\no mask.5a9ab86d-bd32-11ec-b32e-04d9f5803693.jpg
# Collecting images for no mask, image number 17
# data\images\no mask.5a9ab86e-bd32-11ec-9844-04d9f5803693.jpg
# Collecting images for no mask, image number 18
# data\images\no mask.5a9ab86f-bd32-11ec-be2e-04d9f5803693.jpg
# Collecting images for no mask, image number 19
# data\images\no mask.5a9ab870-bd32-11ec-be88-04d9f5803693.jpg
# Collecting images for mask
# Collecting images for mask, image number 0
# data\images\mask.5a9ab871-bd32-11ec-b877-04d9f5803693.jpg
# Collecting images for mask, image number 1
# data\images\mask.5a9ab872-bd32-11ec-a8ae-04d9f5803693.jpg
# Collecting images for mask, image number 2
# data\images\mask.5a9ab873-bd32-11ec-bc60-04d9f5803693.jpg
# Collecting images for mask, image number 3
# data\images\mask.5a9ab874-bd32-11ec-89dd-04d9f5803693.jpg
# Collecting images for mask, image number 4
# data\images\mask.5a9ab875-bd32-11ec-963e-04d9f5803693.jpg
# Collecting images for mask, image number 5
# data\images\mask.5a9ab876-bd32-11ec-a462-04d9f5803693.jpg
# Collecting images for mask, image number 6
# data\images\mask.5a9ab877-bd32-11ec-825a-04d9f5803693.jpg
# Collecting images for mask, image number 7
# data\images\mask.5a9ab878-bd32-11ec-b6f9-04d9f5803693.jpg
# Collecting images for mask, image number 8
# data\images\mask.5a9ab879-bd32-11ec-a424-04d9f5803693.jpg
# Collecting images for mask, image number 9
# data\images\mask.5a9ab87a-bd32-11ec-8951-04d9f5803693.jpg
# Collecting images for mask, image number 10
# data\images\mask.5a9ab87b-bd32-11ec-b618-04d9f5803693.jpg
# Collecting images for mask, image number 11
# data\images\mask.5a9ab87c-bd32-11ec-814a-04d9f5803693.jpg
# Collecting images for mask, image number 12
# data\images\mask.5a9ab87d-bd32-11ec-868a-04d9f5803693.jpg
# Collecting images for mask, image number 13
# data\images\mask.5a9ab87e-bd32-11ec-be84-04d9f5803693.jpg
# Collecting images for mask, image number 14
# data\images\mask.5a9ab87f-bd32-11ec-bfaa-04d9f5803693.jpg
# Collecting images for mask, image number 15
# data\images\mask.5a9ab880-bd32-11ec-b975-04d9f5803693.jpg
# Collecting images for mask, image number 16
# data\images\mask.5a9ab881-bd32-11ec-9e18-04d9f5803693.jpg
# Collecting images for mask, image number 17
# data\images\mask.5a9ab882-bd32-11ec-857b-04d9f5803693.jpg
# Collecting images for mask, image number 18
# data\images\mask.5a9ab883-bd32-11ec-a82c-04d9f5803693.jpg
# Collecting images for mask, image number 19
# data\images\mask.5a9ab884-bd32-11ec-ae99-04d9f5803693.jpg

# %% [markdown]
# ### LabelImg used to label pictures taken

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
#Steps are below to get labelImg running

#created a virtual environment
# !python -m venv venv

# %%
#Activated virtual environment
# !venv\Scripts\Activate.bat

# %%
# !pip install PyQt5 lxml
# Out:
# Collecting pipenv
#   Using cached pipenv-2022.4.8-py2.py3-none-any.whl (3.6 MB)
# Requirement already satisfied: setuptools>=36.2.1 in c:\users\danny\anaconda3\lib\site-packages (from pipenv) (58.0.4)
# Collecting virtualenv-clone>=0.2.5
#   Using cached virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: pip>=18.0 in c:\users\danny\anaconda3\lib\site-packages (from pipenv) (21.2.4)
# Requirement already satisfied: certifi in c:\users\danny\anaconda3\lib\site-packages (from pipenv) (2021.10.8)
# Collecting virtualenv
#   Using cached virtualenv-20.14.1-py2.py3-none-any.whl (8.8 MB)
# Collecting distlib<1,>=0.3.1
#   Using cached distlib-0.3.4-py2.py3-none-any.whl (461 kB)
# Requirement already satisfied: filelock<4,>=3.2 in c:\users\danny\anaconda3\lib\site-packages (from virtualenv->pipenv) (3.3.1)
# Collecting platformdirs<3,>=2
#   Using cached platformdirs-2.5.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: six<2,>=1.9.0 in c:\users\danny\anaconda3\lib\site-packages (from virtualenv->pipenv) (1.16.0)
# Installing collected packages: platformdirs, distlib, virtualenv-clone, virtualenv, pipenv
# Successfully installed distlib-0.3.4 pipenv-2022.4.8 platformdirs-2.5.1 virtualenv-20.14.1 virtualenv-clone-0.5.7

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
#Starts labelmg, used to label each image
# !python labelImg.py

# %%
#A dataset.yml file has to be created according to yolov5 specifications and include the classes from labelImg

# %%
#This runs the training command
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 300 --data dataset.yml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=600, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v6.1-133-g3eefab1 torch 1.8.2+cpu CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5  runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=17
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     59334  models.yolo.Detect                      [17, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 270 layers, 7065478 parameters, 7065478 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
#
# train: Scanning 'C:\Users\Danny\Desktop\object-detection\data\labels.cache' images and labels... 40 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
# train: Scanning 'C:\Users\Danny\Desktop\object-detection\data\labels.cache' images and labels... 40 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
#
# val: Scanning 'C:\Users\Danny\Desktop\object-detection\data\labels.cache' images and labels... 40 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
# val: Scanning 'C:\Users\Danny\Desktop\object-detection\data\labels.cache' images and labels... 40 found, 0 missing, 0 empty, 0 corrupt: 100%|##########| 40/40 [00:00<?, ?it/s]
# Plotting labels to runs\train\exp4\labels.jpg...
#
# AutoAnchor: 5.80 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset
# Image sizes 320 train, 320 val
# Using 8 dataloader workers
# Logging results to runs\train\exp4
# Starting training for 600 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      0/599        0G    0.1105   0.01388   0.07789        33       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      0/599        0G    0.1105   0.01388   0.07789        33       320:  33%|###3      | 1/3 [00:04<00:08,  4.06s/it]
#      0/599        0G    0.1105   0.01535   0.07769        39       320:  33%|###3      | 1/3 [00:06<00:08,  4.06s/it]
#      0/599        0G    0.1105   0.01535   0.07769        39       320:  67%|######6   | 2/3 [00:06<00:02,  2.94s/it]
#      0/599        0G      0.11   0.01675   0.07797        20       320:  67%|######6   | 2/3 [00:07<00:02,  2.94s/it]
#      0/599        0G      0.11   0.01675   0.07797        20       320: 100%|##########| 3/3 [00:07<00:00,  2.22s/it]
#      0/599        0G      0.11   0.01675   0.07797        20       320: 100%|##########| 3/3 [00:07<00:00,  2.53s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.63s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.06it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.05s/it]
#                  all         40         40     0.0296      0.025    0.00302   0.000577
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      1/599        0G    0.1073   0.01389   0.07733        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      1/599        0G    0.1073   0.01389   0.07733        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.20s/it]
#      1/599        0G    0.1064   0.01508   0.07639        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.20s/it]
#      1/599        0G    0.1064   0.01508   0.07639        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.19s/it]
#      1/599        0G    0.1056   0.01537   0.07604        17       320:  67%|######6   | 2/3 [00:05<00:02,  2.19s/it]
#      1/599        0G    0.1056   0.01537   0.07604        17       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#      1/599        0G    0.1056   0.01537   0.07604        17       320: 100%|##########| 3/3 [00:05<00:00,  1.89s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.57s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.09it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.02s/it]
#                  all         40         40     0.0374      0.025    0.00298   0.000541
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      2/599        0G    0.1025   0.01966   0.07288        38       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      2/599        0G    0.1025   0.01966   0.07288        38       320:  33%|###3      | 1/3 [00:02<00:04,  2.15s/it]
#      2/599        0G   0.09924   0.01917   0.07318        32       320:  33%|###3      | 1/3 [00:04<00:04,  2.15s/it]
#      2/599        0G   0.09924   0.01917   0.07318        32       320:  67%|######6   | 2/3 [00:04<00:02,  2.17s/it]
#      2/599        0G   0.09846   0.01699   0.07312        12       320:  67%|######6   | 2/3 [00:05<00:02,  2.17s/it]
#      2/599        0G   0.09846   0.01699   0.07312        12       320: 100%|##########| 3/3 [00:05<00:00,  1.78s/it]
#      2/599        0G   0.09846   0.01699   0.07312        12       320: 100%|##########| 3/3 [00:05<00:00,  1.88s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.03it/s]
#                  all         40         40     0.0383      0.025    0.00258   0.000476
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      3/599        0G    0.0944   0.01957   0.07154        35       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      3/599        0G    0.0944   0.01957   0.07154        35       320:  33%|###3      | 1/3 [00:02<00:04,  2.20s/it]
#      3/599        0G   0.09463   0.01965   0.07193        36       320:  33%|###3      | 1/3 [00:04<00:04,  2.20s/it]
#      3/599        0G   0.09463   0.01965   0.07193        36       320:  67%|######6   | 2/3 [00:04<00:02,  2.18s/it]
#      3/599        0G   0.09214   0.02219   0.07082        20       320:  67%|######6   | 2/3 [00:05<00:02,  2.18s/it]
#      3/599        0G   0.09214   0.02219   0.07082        20       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#      3/599        0G   0.09214   0.02219   0.07082        20       320: 100%|##########| 3/3 [00:05<00:00,  1.89s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.56s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40     0.0343      0.024    0.00276   0.000276
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      4/599        0G   0.08135   0.01892   0.07051        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      4/599        0G   0.08135   0.01892   0.07051        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.20s/it]
#      4/599        0G    0.0852   0.02121   0.06988        38       320:  33%|###3      | 1/3 [00:04<00:04,  2.20s/it]
#      4/599        0G    0.0852   0.02121   0.06988        38       320:  67%|######6   | 2/3 [00:04<00:02,  2.18s/it]
#      4/599        0G   0.08174   0.02227   0.06868        18       320:  67%|######6   | 2/3 [00:05<00:02,  2.18s/it]
#      4/599        0G   0.08174   0.02227   0.06868        18       320: 100%|##########| 3/3 [00:05<00:00,  1.78s/it]
#      4/599        0G   0.08174   0.02227   0.06868        18       320: 100%|##########| 3/3 [00:05<00:00,  1.89s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.52s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.04it/s]
#                  all         40         40     0.0511       0.05     0.0102    0.00133
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      5/599        0G   0.07732   0.02157   0.06443        29       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      5/599        0G   0.07732   0.02157   0.06443        29       320:  33%|###3      | 1/3 [00:02<00:04,  2.17s/it]
#      5/599        0G   0.07844   0.02167   0.06345        31       320:  33%|###3      | 1/3 [00:04<00:04,  2.17s/it]
#      5/599        0G   0.07844   0.02167   0.06345        31       320:  67%|######6   | 2/3 [00:04<00:02,  2.16s/it]
#      5/599        0G   0.07718   0.02122   0.06369        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.16s/it]
#      5/599        0G   0.07718   0.02122   0.06369        16       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
#      5/599        0G   0.07718   0.02122   0.06369        16       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.02it/s]
#                  all         40         40     0.0657       0.05     0.0154    0.00225
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      6/599        0G   0.08373   0.02566   0.06304        44       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      6/599        0G   0.08373   0.02566   0.06304        44       320:  33%|###3      | 1/3 [00:02<00:04,  2.16s/it]
#      6/599        0G   0.07993   0.02408   0.06195        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.16s/it]
#      6/599        0G   0.07993   0.02408   0.06195        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#      6/599        0G     0.077   0.02314   0.06109        14       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#      6/599        0G     0.077   0.02314   0.06109        14       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#      6/599        0G     0.077   0.02314   0.06109        14       320: 100%|##########| 3/3 [00:05<00:00,  1.86s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.52s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.04it/s]
#                  all         40         40     0.0565       0.05     0.0219    0.00343
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      7/599        0G   0.07254   0.02459   0.05888        38       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      7/599        0G   0.07254   0.02459   0.05888        38       320:  33%|###3      | 1/3 [00:02<00:04,  2.13s/it]
#      7/599        0G   0.07512   0.02509   0.05934        39       320:  33%|###3      | 1/3 [00:04<00:04,  2.13s/it]
#      7/599        0G   0.07512   0.02509   0.05934        39       320:  67%|######6   | 2/3 [00:04<00:02,  2.15s/it]
#      7/599        0G   0.07482   0.02987   0.05851        27       320:  67%|######6   | 2/3 [00:05<00:02,  2.15s/it]
#      7/599        0G   0.07482   0.02987   0.05851        27       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
#      7/599        0G   0.07482   0.02987   0.05851        27       320: 100%|##########| 3/3 [00:05<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.55s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40     0.0826      0.075     0.0356    0.00652
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      8/599        0G   0.07245   0.02593   0.05581        36       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      8/599        0G   0.07245   0.02593   0.05581        36       320:  33%|###3      | 1/3 [00:02<00:04,  2.18s/it]
#      8/599        0G   0.07026    0.0224   0.05495        27       320:  33%|###3      | 1/3 [00:04<00:04,  2.18s/it]
#      8/599        0G   0.07026    0.0224   0.05495        27       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#      8/599        0G   0.06988    0.0245   0.05426        20       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#      8/599        0G   0.06988    0.0245   0.05426        20       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#      8/599        0G   0.06988    0.0245   0.05426        20       320: 100%|##########| 3/3 [00:05<00:00,  1.86s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.15it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.04it/s]
#                  all         40         40     0.0834      0.575      0.101     0.0225
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#      9/599        0G   0.07314   0.02107    0.0509        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#      9/599        0G   0.07314   0.02107    0.0509        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.15s/it]
#      9/599        0G   0.07204   0.02703   0.05137        48       320:  33%|###3      | 1/3 [00:04<00:04,  2.15s/it]
#      9/599        0G   0.07204   0.02703   0.05137        48       320:  67%|######6   | 2/3 [00:04<00:02,  2.18s/it]
#      9/599        0G   0.07203   0.02557   0.05092        17       320:  67%|######6   | 2/3 [00:05<00:02,  2.18s/it]
#      9/599        0G   0.07203   0.02557   0.05092        17       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#      9/599        0G   0.07203   0.02557   0.05092        17       320: 100%|##########| 3/3 [00:05<00:00,  1.88s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40      0.254      0.345      0.195     0.0451
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     10/599        0G   0.06502    0.0223   0.05111        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     10/599        0G   0.06502    0.0223   0.05111        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.17s/it]
#     10/599        0G   0.06609    0.0224   0.04867        31       320:  33%|###3      | 1/3 [00:04<00:04,  2.17s/it]
#     10/599        0G   0.06609    0.0224   0.04867        31       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#     10/599        0G   0.06638   0.02324   0.04701        21       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#     10/599        0G   0.06638   0.02324   0.04701        21       320: 100%|##########| 3/3 [00:05<00:00,  1.74s/it]
#     10/599        0G   0.06638   0.02324   0.04701        21       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.53s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40     0.0822      0.075     0.0355    0.00644
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     11/599        0G   0.07121   0.01945   0.04378        30       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     11/599        0G   0.07121   0.01945   0.04378        30       320:  33%|###3      | 1/3 [00:02<00:04,  2.15s/it]
#     11/599        0G   0.06956   0.02007   0.04302        32       320:  33%|###3      | 1/3 [00:04<00:04,  2.15s/it]
#     11/599        0G   0.06956   0.02007   0.04302        32       320:  67%|######6   | 2/3 [00:04<00:02,  2.15s/it]
#     11/599        0G   0.07141   0.01928   0.04218        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.15s/it]
#     11/599        0G   0.07141   0.01928   0.04218        16       320: 100%|##########| 3/3 [00:05<00:00,  1.72s/it]
#     11/599        0G   0.07141   0.01928   0.04218        16       320: 100%|##########| 3/3 [00:05<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40      0.308        0.8      0.341     0.0728
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     12/599        0G   0.07763   0.02122   0.04374        37       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     12/599        0G   0.07763   0.02122   0.04374        37       320:  33%|###3      | 1/3 [00:02<00:04,  2.21s/it]
#     12/599        0G   0.07202   0.01937   0.04184        26       320:  33%|###3      | 1/3 [00:04<00:04,  2.21s/it]
#     12/599        0G   0.07202   0.01937   0.04184        26       320:  67%|######6   | 2/3 [00:04<00:02,  2.17s/it]
#     12/599        0G   0.07142   0.01957   0.04041        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.17s/it]
#     12/599        0G   0.07142   0.01957   0.04041        16       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#     12/599        0G   0.07142   0.01957   0.04041        16       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.66s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.06s/it]
#                  all         40         40      0.225      0.225      0.113     0.0142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     13/599        0G    0.0796   0.02159   0.03796        39       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     13/599        0G    0.0796   0.02159   0.03796        39       320:  33%|###3      | 1/3 [00:02<00:04,  2.12s/it]
#     13/599        0G   0.07817   0.01881    0.0382        27       320:  33%|###3      | 1/3 [00:04<00:04,  2.12s/it]
#     13/599        0G   0.07817   0.01881    0.0382        27       320:  67%|######6   | 2/3 [00:04<00:02,  2.16s/it]
#     13/599        0G   0.07918   0.01805   0.03644        15       320:  67%|######6   | 2/3 [00:05<00:02,  2.16s/it]
#     13/599        0G   0.07918   0.01805   0.03644        15       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#     13/599        0G   0.07918   0.01805   0.03644        15       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.57s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.00it/s]
#                  all         40         40        0.1      0.825      0.101     0.0114
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     14/599        0G   0.07953    0.0205   0.03776        40       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     14/599        0G   0.07953    0.0205   0.03776        40       320:  33%|###3      | 1/3 [00:02<00:04,  2.20s/it]
#     14/599        0G   0.07731   0.01873   0.03739        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.20s/it]
#     14/599        0G   0.07731   0.01873   0.03739        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.16s/it]
#     14/599        0G     0.077   0.01726   0.03694        14       320:  67%|######6   | 2/3 [00:05<00:02,  2.16s/it]
#     14/599        0G     0.077   0.01726   0.03694        14       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#     14/599        0G     0.077   0.01726   0.03694        14       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.57s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40      0.209        0.5      0.194      0.038
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     15/599        0G   0.06395   0.02621   0.03462        43       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     15/599        0G   0.06395   0.02621   0.03462        43       320:  33%|###3      | 1/3 [00:02<00:04,  2.11s/it]
#     15/599        0G   0.06526   0.02188   0.03696        31       320:  33%|###3      | 1/3 [00:04<00:04,  2.11s/it]
#     15/599        0G   0.06526   0.02188   0.03696        31       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#     15/599        0G   0.07488   0.01904   0.03539        15       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#     15/599        0G   0.07488   0.01904   0.03539        15       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#     15/599        0G   0.07488   0.01904   0.03539        15       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.61s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.03s/it]
#                  all         40         40     0.0309       0.85     0.0346    0.00994
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     16/599        0G   0.09128   0.01232    0.0348        27       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     16/599        0G   0.09128   0.01232    0.0348        27       320:  33%|###3      | 1/3 [00:02<00:04,  2.16s/it]
#     16/599        0G   0.08733   0.01442   0.03451        36       320:  33%|###3      | 1/3 [00:04<00:04,  2.16s/it]
#     16/599        0G   0.08733   0.01442   0.03451        36       320:  67%|######6   | 2/3 [00:04<00:02,  2.15s/it]
#     16/599        0G   0.08491   0.01384   0.03532        13       320:  67%|######6   | 2/3 [00:05<00:02,  2.15s/it]
#     16/599        0G   0.08491   0.01384   0.03532        13       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#     16/599        0G   0.08491   0.01384   0.03532        13       320: 100%|##########| 3/3 [00:05<00:00,  1.86s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.56s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.01it/s]
#                  all         40         40      0.186       0.55      0.199     0.0227
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     17/599        0G   0.07437   0.01484    0.0342        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     17/599        0G   0.07437   0.01484    0.0342        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.12s/it]
#     17/599        0G   0.07622   0.01511   0.03314        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.12s/it]
#     17/599        0G   0.07622   0.01511   0.03314        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.12s/it]
#     17/599        0G   0.07618   0.01535   0.03304        18       320:  67%|######6   | 2/3 [00:05<00:02,  2.12s/it]
#     17/599        0G   0.07618   0.01535   0.03304        18       320: 100%|##########| 3/3 [00:05<00:00,  1.72s/it]
#     17/599        0G   0.07618   0.01535   0.03304        18       320: 100%|##########| 3/3 [00:05<00:00,  1.83s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.71s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.02it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:02<00:00,  1.09s/it]
#                  all         40         40      0.133      0.125     0.0696     0.0174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     18/599        0G   0.09315   0.01634   0.03264        44       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     18/599        0G   0.09315   0.01634   0.03264        44       320:  33%|###3      | 1/3 [00:02<00:04,  2.18s/it]
#     18/599        0G   0.09508   0.01619   0.03242        43       320:  33%|###3      | 1/3 [00:04<00:04,  2.18s/it]
#     18/599        0G   0.09508   0.01619   0.03242        43       320:  67%|######6   | 2/3 [00:04<00:02,  2.15s/it]
#     18/599        0G   0.09358   0.01595   0.03227        20       320:  67%|######6   | 2/3 [00:05<00:02,  2.15s/it]
#     18/599        0G   0.09358   0.01595   0.03227        20       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#     18/599        0G   0.09358   0.01595   0.03227        20       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.06it/s]
#                  all         40         40     0.0705       0.95     0.0807     0.0148
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     19/599        0G   0.07566   0.01277   0.02969        29       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     19/599        0G   0.07566   0.01277   0.02969        29       320:  33%|###3      | 1/3 [00:02<00:04,  2.10s/it]
#     19/599        0G   0.07754   0.01294   0.03088        31       320:  33%|###3      | 1/3 [00:04<00:04,  2.10s/it]
#     19/599        0G   0.07754   0.01294   0.03088        31       320:  67%|######6   | 2/3 [00:04<00:02,  2.11s/it]
#     19/599        0G   0.07962   0.01394   0.03155        19       320:  67%|######6   | 2/3 [00:05<00:02,  2.11s/it]
#     19/599        0G   0.07962   0.01394   0.03155        19       320: 100%|##########| 3/3 [00:05<00:00,  1.74s/it]
#     19/599        0G   0.07962   0.01394   0.03155        19       320: 100%|##########| 3/3 [00:05<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.03it/s]
#                  all         40         40     0.0531      0.925     0.0564     0.0219
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     20/599        0G   0.08178   0.01244   0.02888        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     20/599        0G   0.08178   0.01244   0.02888        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.12s/it]
#     20/599        0G   0.08498   0.01297    0.0304        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.12s/it]
#     20/599        0G   0.08498   0.01297    0.0304        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.17s/it]
#     20/599        0G   0.08332   0.01275   0.02999        13       320:  67%|######6   | 2/3 [00:05<00:02,  2.17s/it]
#     20/599        0G   0.08332   0.01275   0.02999        13       320: 100%|##########| 3/3 [00:05<00:00,  1.78s/it]
#     20/599        0G   0.08332   0.01275   0.02999        13       320: 100%|##########| 3/3 [00:05<00:00,  1.88s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.06it/s]
#                  all         40         40      0.185      0.249      0.206     0.0291
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     21/599        0G    0.0828   0.01503   0.02922        40       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     21/599        0G    0.0828   0.01503   0.02922        40       320:  33%|###3      | 1/3 [00:02<00:04,  2.10s/it]
#     21/599        0G   0.08271   0.01459    0.0301        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.10s/it]
#     21/599        0G   0.08271   0.01459    0.0301        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.11s/it]
#     21/599        0G   0.08187   0.01404   0.02948        15       320:  67%|######6   | 2/3 [00:05<00:02,  2.11s/it]
#     21/599        0G   0.08187   0.01404   0.02948        15       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
#     21/599        0G   0.08187   0.01404   0.02948        15       320: 100%|##########| 3/3 [00:05<00:00,  1.83s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.07it/s]
#                  all         40         40      0.201      0.575      0.231     0.0613
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     22/599        0G   0.08323   0.01538   0.02987        37       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     22/599        0G   0.08323   0.01538   0.02987        37       320:  33%|###3      | 1/3 [00:02<00:04,  2.13s/it]
#     22/599        0G   0.08216   0.01522    0.0297        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.13s/it]
#     22/599        0G   0.08216   0.01522    0.0297        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#     22/599        0G   0.07856   0.01416   0.03079        12       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#     22/599        0G   0.07856   0.01416   0.03079        12       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#     22/599        0G   0.07856   0.01416   0.03079        12       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.11it/s]
#                  all         40         40      0.291        0.7       0.28     0.0439
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     23/599        0G   0.07849   0.01478   0.02655        31       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     23/599        0G   0.07849   0.01478   0.02655        31       320:  33%|###3      | 1/3 [00:02<00:04,  2.13s/it]
#     23/599        0G     0.078   0.01518   0.02691        35       320:  33%|###3      | 1/3 [00:04<00:04,  2.13s/it]
#     23/599        0G     0.078   0.01518   0.02691        35       320:  67%|######6   | 2/3 [00:04<00:02,  2.13s/it]
#     23/599        0G   0.07771   0.01598   0.02664        20       320:  67%|######6   | 2/3 [00:05<00:02,  2.13s/it]
#     23/599        0G   0.07771   0.01598   0.02664        20       320: 100%|##########| 3/3 [00:05<00:00,  1.74s/it]
#     23/599        0G   0.07771   0.01598   0.02664        20       320: 100%|##########| 3/3 [00:05<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.12it/s]
#                  all         40         40      0.216        0.7      0.243     0.0641
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     24/599        0G   0.07035   0.01505   0.02754        30       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     24/599        0G   0.07035   0.01505   0.02754        30       320:  33%|###3      | 1/3 [00:02<00:04,  2.12s/it]
#     24/599        0G   0.06525   0.01384   0.02878        23       320:  33%|###3      | 1/3 [00:04<00:04,  2.12s/it]
#     24/599        0G   0.06525   0.01384   0.02878        23       320:  67%|######6   | 2/3 [00:04<00:02,  2.12s/it]
#     24/599        0G     0.068   0.01424   0.02854        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.12s/it]
#     24/599        0G     0.068   0.01424   0.02854        16       320: 100%|##########| 3/3 [00:05<00:00,  1.74s/it]
#     24/599        0G     0.068   0.01424   0.02854        16       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.10it/s]
#                  all         40         40      0.241      0.775      0.427      0.184
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     25/599        0G   0.07699    0.0195   0.02547        44       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     25/599        0G   0.07699    0.0195   0.02547        44       320:  33%|###3      | 1/3 [00:02<00:04,  2.13s/it]
#     25/599        0G     0.078    0.0164   0.02448        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.13s/it]
#     25/599        0G     0.078    0.0164   0.02448        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.13s/it]
#     25/599        0G   0.07888   0.01711   0.02441        20       320:  67%|######6   | 2/3 [00:05<00:02,  2.13s/it]
#     25/599        0G   0.07888   0.01711   0.02441        20       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
#     25/599        0G   0.07888   0.01711   0.02441        20       320: 100%|##########| 3/3 [00:05<00:00,  1.84s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.08it/s]
#                  all         40         40      0.318      0.871      0.474      0.221
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     26/599        0G   0.07586   0.02001   0.02192        44       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     26/599        0G   0.07586   0.02001   0.02192        44       320:  33%|###3      | 1/3 [00:02<00:04,  2.12s/it]
#     26/599        0G   0.07694   0.01815   0.02308        36       320:  33%|###3      | 1/3 [00:04<00:04,  2.12s/it]
#     26/599        0G   0.07694   0.01815   0.02308        36       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#     26/599        0G   0.07486   0.01847   0.02463        21       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#     26/599        0G   0.07486   0.01847   0.02463        21       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#     26/599        0G   0.07486   0.01847   0.02463        21       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.08it/s]
#                  all         40         40      0.427      0.872      0.473      0.228
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#     27/599        0G   0.07613   0.01941   0.02162        47       320:   0%|          | 0/3 [00:02<?, ?it/s]
#     27/599        0G   0.07613   0.01941   0.02162        47       320:  33%|###3      | 1/3 [00:02<00:04,  2.13s/it]
#     27/599        0G   0.07463   0.01719   0.02128        30       320:  33%|###3      | 1/3 [00:04<00:04,  2.13s/it]
#     27/599        0G   0.07463   0.01719   0.02128        30       320:  67%|######6   | 2/3 [00:04<00:02,  2.12s/it]
#     27/599        0G    0.0754   0.01638   0.02175        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.12s/it]
#     27/599        0G    0.0754   0.01638   0.02175        16       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
# ...
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                  all         40         40      0.999          1      0.995       0.72
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    214/599        0G   0.03813  0.007353  0.008401        33       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    214/599        0G   0.03813  0.007353  0.008401        33       320:  33%|###3      | 1/3 [00:02<00:04,  2.17s/it]
#    214/599        0G   0.03672  0.007657   0.00613        36       320:  33%|###3      | 1/3 [00:04<00:04,  2.17s/it]
#    214/599        0G   0.03672  0.007657   0.00613        36       320:  67%|######6   | 2/3 [00:04<00:02,  2.18s/it]
#    214/599        0G   0.03431  0.007878  0.006419        17       320:  67%|######6   | 2/3 [00:05<00:02,  2.18s/it]
#    214/599        0G   0.03431  0.007878  0.006419        17       320: 100%|##########| 3/3 [00:05<00:00,  1.76s/it]
#    214/599        0G   0.03431  0.007878  0.006419        17       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.31it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                  all         40         40      0.999          1      0.995      0.803
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    215/599        0G   0.03212  0.007561  0.003357        33       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    215/599        0G   0.03212  0.007561  0.003357        33       320:  33%|###3      | 1/3 [00:02<00:04,  2.16s/it]
#    215/599        0G   0.03327  0.007929  0.003728        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.16s/it]
#    215/599        0G   0.03327  0.007929  0.003728        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.17s/it]
#    215/599        0G   0.03294  0.007805  0.003494        17       320:  67%|######6   | 2/3 [00:05<00:02,  2.17s/it]
#    215/599        0G   0.03294  0.007805  0.003494        17       320: 100%|##########| 3/3 [00:05<00:00,  1.82s/it]
#    215/599        0G   0.03294  0.007805  0.003494        17       320: 100%|##########| 3/3 [00:05<00:00,  1.92s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.14it/s]
#                  all         40         40      0.999          1      0.995      0.688
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    216/599        0G    0.0372  0.007712  0.004252        34       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    216/599        0G    0.0372  0.007712  0.004252        34       320:  33%|###3      | 1/3 [00:02<00:04,  2.35s/it]
#    216/599        0G   0.03817  0.008286  0.003846        35       320:  33%|###3      | 1/3 [00:04<00:04,  2.35s/it]
#    216/599        0G   0.03817  0.008286  0.003846        35       320:  67%|######6   | 2/3 [00:04<00:02,  2.31s/it]
#    216/599        0G   0.03952  0.007971   0.00373        16       320:  67%|######6   | 2/3 [00:06<00:02,  2.31s/it]
#    216/599        0G   0.03952  0.007971   0.00373        16       320: 100%|##########| 3/3 [00:06<00:00,  1.90s/it]
#    216/599        0G   0.03952  0.007971   0.00373        16       320: 100%|##########| 3/3 [00:06<00:00,  2.02s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.16it/s]
#                  all         40         40      0.999          1      0.995      0.688
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    217/599        0G   0.04147  0.009163  0.003089        38       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    217/599        0G   0.04147  0.009163  0.003089        38       320:  33%|###3      | 1/3 [00:02<00:04,  2.17s/it]
#    217/599        0G    0.0395  0.008152  0.003057        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.17s/it]
#    217/599        0G    0.0395  0.008152  0.003057        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#    217/599        0G   0.03665  0.007889  0.003936        16       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#    217/599        0G   0.03665  0.007889  0.003936        16       320: 100%|##########| 3/3 [00:05<00:00,  1.73s/it]
#    217/599        0G   0.03665  0.007889  0.003936        16       320: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.14it/s]
#                  all         40         40      0.999          1      0.995      0.712
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    218/599        0G    0.0391  0.008519   0.00375        38       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    218/599        0G    0.0391  0.008519   0.00375        38       320:  33%|###3      | 1/3 [00:02<00:04,  2.28s/it]
#    218/599        0G   0.03905  0.008196  0.003725        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.28s/it]
#    218/599        0G   0.03905  0.008196  0.003725        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.24s/it]
#    218/599        0G   0.03674  0.007182  0.003494         9       320:  67%|######6   | 2/3 [00:05<00:02,  2.24s/it]
#    218/599        0G   0.03674  0.007182  0.003494         9       320: 100%|##########| 3/3 [00:05<00:00,  1.80s/it]
#    218/599        0G   0.03674  0.007182  0.003494         9       320: 100%|##########| 3/3 [00:05<00:00,  1.92s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.15it/s]
#                  all         40         40      0.999          1      0.995      0.758
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    219/599        0G   0.03855  0.006889  0.003068        30       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    219/599        0G   0.03855  0.006889  0.003068        30       320:  33%|###3      | 1/3 [00:02<00:04,  2.20s/it]
#    219/599        0G   0.04031  0.007134  0.003506        33       320:  33%|###3      | 1/3 [00:04<00:04,  2.20s/it]
#    219/599        0G   0.04031  0.007134  0.003506        33       320:  67%|######6   | 2/3 [00:04<00:02,  2.17s/it]
#    219/599        0G   0.04027   0.00767  0.003332        21       320:  67%|######6   | 2/3 [00:05<00:02,  2.17s/it]
#    219/599        0G   0.04027   0.00767  0.003332        21       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#    219/599        0G   0.04027   0.00767  0.003332        21       320: 100%|##########| 3/3 [00:05<00:00,  1.88s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.31it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
#                  all         40         40      0.999          1      0.995      0.751
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    220/599        0G   0.04108  0.007636   0.00401        30       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    220/599        0G   0.04108  0.007636   0.00401        30       320:  33%|###3      | 1/3 [00:02<00:04,  2.14s/it]
#    220/599        0G   0.04111  0.007615  0.005222        30       320:  33%|###3      | 1/3 [00:04<00:04,  2.14s/it]
#    220/599        0G   0.04111  0.007615  0.005222        30       320:  67%|######6   | 2/3 [00:04<00:02,  2.14s/it]
#    220/599        0G   0.04119  0.007854  0.005916        17       320:  67%|######6   | 2/3 [00:05<00:02,  2.14s/it]
#    220/599        0G   0.04119  0.007854  0.005916        17       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#    220/599        0G   0.04119  0.007854  0.005916        17       320: 100%|##########| 3/3 [00:05<00:00,  1.86s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.29it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.15it/s]
#                  all         40         40      0.999          1      0.995      0.751
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    221/599        0G   0.04286   0.00653  0.003588        30       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    221/599        0G   0.04286   0.00653  0.003588        30       320:  33%|###3      | 1/3 [00:02<00:04,  2.16s/it]
#    221/599        0G   0.03873  0.007434  0.003825        34       320:  33%|###3      | 1/3 [00:04<00:04,  2.16s/it]
#    221/599        0G   0.03873  0.007434  0.003825        34       320:  67%|######6   | 2/3 [00:04<00:02,  2.16s/it]
#    221/599        0G   0.03847  0.008439  0.003601        25       320:  67%|######6   | 2/3 [00:05<00:02,  2.16s/it]
#    221/599        0G   0.03847  0.008439  0.003601        25       320: 100%|##########| 3/3 [00:05<00:00,  1.75s/it]
#    221/599        0G   0.03847  0.008439  0.003601        25       320: 100%|##########| 3/3 [00:05<00:00,  1.87s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.15it/s]
#                  all         40         40      0.999          1      0.995      0.741
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#    222/599        0G   0.03554  0.008302   0.00394        36       320:   0%|          | 0/3 [00:02<?, ?it/s]
#    222/599        0G   0.03554  0.008302   0.00394        36       320:  33%|###3      | 1/3 [00:02<00:04,  2.21s/it]
#    222/599        0G   0.03558  0.007793   0.00463        35       320:  33%|###3      | 1/3 [00:04<00:04,  2.21s/it]
#    222/599        0G   0.03558  0.007793   0.00463        35       320:  67%|######6   | 2/3 [00:04<00:02,  2.19s/it]
#    222/599        0G   0.03406  0.007248  0.004592        12       320:  67%|######6   | 2/3 [00:05<00:02,  2.19s/it]
#    222/599        0G   0.03406  0.007248  0.004592        12       320: 100%|##########| 3/3 [00:05<00:00,  1.77s/it]
#    222/599        0G   0.03406  0.007248  0.004592        12       320: 100%|##########| 3/3 [00:05<00:00,  1.88s/it]
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.30s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.33it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.20it/s]
#                  all         40         40      0.999          1      0.995      0.793
# Stopping training early as no improvement observed in last 100 epochs. Best results observed at epoch 122, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 223 epochs completed in 0.471 hours.
# Optimizer stripped from runs\train\exp4\weights\last.pt, 14.4MB
# Optimizer stripped from runs\train\exp4\weights\best.pt, 14.4MB
#
# Validating runs\train\exp4\weights\best.pt...
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/2 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  50%|#####     | 1/2 [00:01<00:01,  1.29s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 2/2 [00:01<00:00,  1.19it/s]
#                  all         40         40      0.978          1      0.995      0.868
#                 mask         40         20      0.956          1      0.995      0.906
#              no mask         40         20          1          1      0.995       0.83
# Results saved to runs\train\exp4

# %% [markdown]
# #  Face Mask Model

# %%
#setting model to be model we just trained
model = torch.hub.load('ultralytics/yolov5','custom', path='yolov5/runs/train/exp3/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Danny/.cache\torch\hub\master.zip
# YOLOv5  2022-4-16 torch 1.8.2+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = 'https://2rdnmg1qbg403gumla1v9i2h-wpengine.netdna-ssl.com/wp-content/uploads/sites/3/2020/10/faceMasksProtectCouple-1273627467-770x553-1-650x428.jpg'

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 428x650 2 masks
# Speed: 204.1ms pre-process, 230.9ms inference, 0.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
#Live feed of face mask detection
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    results = model(frame)
    
    cv2.imshow('Object Detection', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
